# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateshdukuru/GDSC-2k23/blob/main/sales_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the liberies which are necessary for this Advertising 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read csv file using pandas library
df = pd.read_csv("/content/Advertising.csv")

# %%
#df for print
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
#it will print first five rows
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#information about the rows and columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
#it is describe about the data set rows and columns
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
#shape will tell length of the rows and columns
df.shape
# Out:
# (200, 5)

# %%
#isnull function will check the given dataset contain null values or not?
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
#iloc is use to extract independent variables
x =df.iloc[:,0:-1]

# %%
x
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
#iloc is use to extract independent variables
y=df.iloc[:,0:-1]

#  : first semicolon for rows
#  : second semicolon for columns
#   -1 dont want to take last column dependent variables

# %%
y
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
#import sklearn library and train and test the x and y  variables
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
x_train
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 116         117  139.2   14.3       25.6
# 138         139   43.0   25.9       20.5
# 155         156    4.1   11.6        5.7
# 82           83   75.3   20.3       32.5
# 160         161  172.5   18.1       30.7
# ..          ...    ...    ...        ...
# 58           59  210.8   49.6       37.7
# 21           22  237.4    5.1       23.5
# 49           50   66.9   11.7       36.8
# 64           65  131.1   42.8       28.9
# 68           69  237.4   27.5       11.0
#
# [160 rows x 4 columns]

# %%
y_train
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 116         117  139.2   14.3       25.6
# 138         139   43.0   25.9       20.5
# 155         156    4.1   11.6        5.7
# 82           83   75.3   20.3       32.5
# 160         161  172.5   18.1       30.7
# ..          ...    ...    ...        ...
# 58           59  210.8   49.6       37.7
# 21           22  237.4    5.1       23.5
# 49           50   66.9   11.7       36.8
# 64           65  131.1   42.8       28.9
# 68           69  237.4   27.5       11.0
#
# [160 rows x 4 columns]

# %%
x_test
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 56           57    7.3   28.1       41.4
# 37           38   74.7   49.4       45.7
# 67           68  139.3   14.5       10.2
# 79           80  116.0    7.7       23.1
# 80           81   76.4   26.7       22.3
# 188         189  286.0   13.9        3.7
# 183         184  287.6   43.0       71.8
# 10           11   66.1    5.8       24.2
# 128         129  220.3   49.0        3.2
# 62           63  239.3   15.5       27.3
# 65           66   69.0    9.3        0.9
# 17           18  281.4   39.6       55.8
# 133         134  219.8   33.5       45.1
# 195         196   38.2    3.7       13.8
# 146         147  240.1    7.3        8.7
# 38           39   43.1   26.7       35.1
# 173         174  168.4    7.1       12.8
# 149         150   44.7   25.8       20.6
# 93           94  250.9   36.5       72.3
# 29           30   70.6   16.0       40.8
# 0             1  230.1   37.8       69.2
# 2             3   17.2   45.9       69.3
# ...

# %%
y_test
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 56           57    7.3   28.1       41.4
# 37           38   74.7   49.4       45.7
# 67           68  139.3   14.5       10.2
# 79           80  116.0    7.7       23.1
# 80           81   76.4   26.7       22.3
# 188         189  286.0   13.9        3.7
# 183         184  287.6   43.0       71.8
# 10           11   66.1    5.8       24.2
# 128         129  220.3   49.0        3.2
# 62           63  239.3   15.5       27.3
# 65           66   69.0    9.3        0.9
# 17           18  281.4   39.6       55.8
# 133         134  219.8   33.5       45.1
# 195         196   38.2    3.7       13.8
# 146         147  240.1    7.3        8.7
# 38           39   43.1   26.7       35.1
# 173         174  168.4    7.1       12.8
# 149         150   44.7   25.8       20.6
# 93           94  250.9   36.5       72.3
# 29           30   70.6   16.0       40.8
# 0             1  230.1   37.8       69.2
# 2             3   17.2   45.9       69.3
# ...

# %%
#from sklearn import LinearRegression
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
#using lr fit the x,y variables
lr.fit(x_train ,y_train)
# Out:
# LinearRegression()

# %%
#prediction 
y_pred=lr.predict(x_test)

# %%
#from matplotlib library to drawn this plot
plt.scatter(y_test,y_pred,c='r')

# %%
plt.scatter(x_test,y_pred,c ='y')

# %%
#import sklearn metrics
from sklearn.metrics import r2_score

# %%
#predict the accuracy of the sales prediction
r2_score(y_test,y_pred)*100
# Out:
# 100.0
